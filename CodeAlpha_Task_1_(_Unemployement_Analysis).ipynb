# %% [markdown]
# <a href="https://colab.research.google.com/github/SardarAmmer/CodeAlpha-Internship-Projects/blob/main/CodeAlpha_Task_1_(_Unemployement_Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Task1 Umemployment Analysis, Exploring Dataset

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Unemployment_Rate_upto_11_2020.csv')
df.head()
print(df.shape)
df.info()
df.describe()
# Out:
#                                           0
# Region                                    0
#  Date                                     0
#  Frequency                                0
#  Estimated Unemployment Rate (%)          0
#  Estimated Employed                       0
#  Estimated Labour Participation Rate (%)  0
# Region.1                                  0
# longitude                                 0
# latitude                                  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
# ...
